# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenkumarr-45/ML_Algorithms/blob/main/Restaurant_statistical_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('Restaurant.xlsx')
df.head()
b=df[df['INVOICE_NO']==117]
print(b['AMOUNT'].sum())
# Out:
# 625.0

# %%
sales=df.groupby('ITEM')['SUB_TOTAL'].sum().sort_values(ascending=False).head(5)
quan=df.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=False).head(5)
sns.barplot(sales)
sns.barplot(quan)
# Out:
# <Axes: xlabel='ITEM', ylabel='SUB_TOTAL'>

# %%
c=df[df['DATE']=='2.10.2023']
least=c.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=True).head(5)
sns.barplot(least)
# Out:
# <Axes: xlabel='ITEM', ylabel='QUANTITY'>

# %%
high=df.groupby('INVOICE_NO')['AMOUNT'].sum().sort_values(ascending=False).head(1)
print(high)
# Out:
# INVOICE_NO
# 63    941.0
# Name: AMOUNT, dtype: float64

# %%
data=pd.read_csv('Data.csv')
data.head()
# Out:
#          Date            Timestamp  Invoice No.             Item Name  Price  \
# 0  2023-09-19  2023-09-19 22:03:44        28389                Kulcha   55.0
# 1  2023-09-19  2023-09-19 22:03:44        28389                Parota   30.0
# 2  2023-09-19  2023-09-19 22:03:44        28389       Mushroom Masala  150.0
# 3  2023-09-19  2023-09-19 22:03:44        28389  Paneer Butter Masala  150.0
# 4  2023-09-19  2023-09-19 22:03:44        28389              Gobi- 65  120.0
#
#    Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0   1.0       55.0       0.0  2.76        57.76         16      biller
# 1   4.0      120.0       0.0  6.00       126.00         16      biller
# 2   1.0      150.0       0.0  7.50       157.50         16      biller
# 3   1.0      150.0       0.0  7.50       157.50         16      biller
# 4   1.0      120.0       0.0  6.00       126.00         16      biller
#
#    Covers Variation       Category  HSN
# ...

# %%
a=data.groupby('Date')['Final Total'].mean().sort_values(ascending=False).head(1)
print(a)
# Out:
# Date
# 2023-07-19    319.837857
# Name: Final Total, dtype: float64

# %%
b=data['Invoice No.'].nunique()
print(b)
# Out:
# 2199

# %%
c=data[(data['Date']>='2023-09-01') & (data['Date']<='2023-09-31')]
d=c.groupby('Item Name')['Qty.'].sum().sort_values(ascending=False).head(1)
print(d)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    268.0
# Name: Qty., dtype: float64

# %%
df=data[(data['Date']>='2023-07-01') & (data['Date']<='2023-07-31')]
q=df.groupby('Category')['Qty.'].sum().sort_values(ascending=True).head(3)
sns.barplot(q)
# Out:
# <Axes: xlabel='Category', ylabel='Qty.'>

# %%
pi=df.groupby('Category')['Qty.'].sum()
plt.pie(pi,labels=pi.index)
plt.show()

# %%
print(data['Final Total'].sum()/data['Invoice No.'].nunique())
# Out:
# 549.4027239654388
